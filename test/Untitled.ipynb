# %%
import pandas as pd

# %%
df = pd.read_csv('DataAnalyst.csv',encoding='gbk')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6876 entries, 0 to 6875
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   city               6876 non-null   object
#  1   companyFullName    6876 non-null   object
#  2   companyId          6876 non-null   int64
#  3   companyLabelList   6170 non-null   object
#  4   companyShortName   6876 non-null   object
#  5   companySize        6876 non-null   object
#  6   businessZones      4873 non-null   object
#  7   firstType          6869 non-null   object
#  8   secondType         6870 non-null   object
#  9   education          6876 non-null   object
#  10  industryField      6876 non-null   object
#  11  positionId         6876 non-null   int64
#  12  positionAdvantage  6876 non-null   object
#  13  positionName       6876 non-null   object
#  14  positionLables     6844 non-null   object
#  15  salary             6876 non-null   object
# ...

# %%
df.head(10)
# Out:
#   city    companyFullName  companyId                  companyLabelList  \
# 0   上海     纽海信息技术(上海)有限公司       8581  ['技能培训', '节日礼物', '带薪年假', '岗位晋升']
# 1   上海   上海点荣金融信息服务有限责任公司      23177  ['节日礼物', '带薪年假', '岗位晋升', '扁平管理']
# 2   上海     上海晶樵网络信息技术有限公司      57561  ['技能培训', '绩效奖金', '岗位晋升', '管理规范']
# 3   上海  杭州数云信息技术有限公司上海分公司       7502  ['绩效奖金', '股票期权', '五险一金', '通讯津贴']
# 4   上海     上海银基富力信息技术有限公司     130876  ['年底双薪', '通讯津贴', '定期体检', '绩效奖金']
# 5   上海      上海青之桐投资管理有限公司      28095    ['美女多', '出国旅游', '不打卡', '带薪年假']
# 6   上海       上海好体信息科技有限公司       2002   ['年底双薪', '股票期权', '扁平管理', '领导好']
# 7   上海     上海安硕信息技术股份有限公司      21863  ['岗位晋升', '顶尖团队', '福利优厚', '股票期权']
# 8   上海     上海崇杏健康管理咨询有限公司     121208   ['扁平管理', '弹性工作', '岗位晋升', '领导好']
# 9   上海   五五海淘（上海）科技股份有限公司      58109  ['股票期权', '带薪年假', '绩效奖金', '岗位晋升']
#
#   companyShortName companySize              businessZones  firstType  \
# 0              1号店     2000人以上                     ['张江']         技术
# ...

# %%
df.tail()
# Out:
#      city companyFullName  companyId companyLabelList companyShortName  \
# 6871   北京  北京亿盛融华投资管理有限公司     151898              NaN             亿盛资本
# 6872   北京  北京亿盛融华投资管理有限公司     151898              NaN             亿盛资本
# 6873   北京  北京亿盛融华投资管理有限公司     151898              NaN             亿盛资本
# 6874   北京  北京亿盛融华投资管理有限公司     151898              NaN             亿盛资本
# 6875   北京  北京亿盛融华投资管理有限公司     151898              NaN             亿盛资本
#
#      companySize businessZones  firstType secondType education industryField  \
# 6871    150-500人           NaN  市场/商务/销售类         销售        大专         金融、教育
# 6872    150-500人           NaN  产品/需求/项目类       项目管理        大专         金融、教育
# 6873    150-500人           NaN         其他    房地产|建筑业        大专         金融、教育
# 6874    150-500人           NaN  市场/商务/销售类         销售        大专         金融、教育
# 6875    150-500人           NaN        金融类         风控        不限         金融、教育
#
#       positionId                                positionAdvantage  \
# ...

# %%
df.sort_values(by = 'avg')
# Out:
#      city    companyFullName  companyId                  companyLabelList  \
# 0      上海     纽海信息技术(上海)有限公司       8581  ['技能培训', '节日礼物', '带薪年假', '岗位晋升']
# 1      上海   上海点荣金融信息服务有限责任公司      23177  ['节日礼物', '带薪年假', '岗位晋升', '扁平管理']
# 2      上海     上海晶樵网络信息技术有限公司      57561  ['技能培训', '绩效奖金', '岗位晋升', '管理规范']
# 3      上海  杭州数云信息技术有限公司上海分公司       7502  ['绩效奖金', '股票期权', '五险一金', '通讯津贴']
# 4      上海     上海银基富力信息技术有限公司     130876  ['年底双薪', '通讯津贴', '定期体检', '绩效奖金']
# ...   ...                ...        ...                               ...
# 6871   北京     北京亿盛融华投资管理有限公司     151898                               NaN
# 6872   北京     北京亿盛融华投资管理有限公司     151898                               NaN
# 6873   北京     北京亿盛融华投资管理有限公司     151898                               NaN
# 6874   北京     北京亿盛融华投资管理有限公司     151898                               NaN
# 6875   北京     北京亿盛融华投资管理有限公司     151898                               NaN
#
#      companyShortName companySize           businessZones  firstType  \
# ...

# %%
df.sort_values(['avg','city'], ascending = False)
# Out:
#      city       companyFullName  companyId                  companyLabelList  \
# 4962   长沙          湖南纵驰健康管理有限公司     149263                               NaN
# 4963   长沙            湖南惠农科技有限公司      27754  ['绩效奖金', '五险一金', '带薪年假', '节日礼物']
# 4964   长沙              五八到家有限公司     125448   ['年底双薪', '绩效奖金', '带薪年假', 'O2O']
# 4965   长沙      湖南快乐阳光互动娱乐传媒有限公司      26785   ['节日礼物', '免费班车', '带薪年假', '领导好']
# 4966   长沙  自由飞越国际航空技术服务（北京）有限公司      53480  ['节日礼物', '股票期权', '带薪年假', '绩效奖金']
# ...   ...                   ...        ...                               ...
# 975    上海          北京三快在线科技有限公司      50702   ['技能培训', '绩效奖金', '岗位晋升', '领导好']
# 976    上海          北京三快在线科技有限公司      50702   ['技能培训', '绩效奖金', '岗位晋升', '领导好']
# 977    上海          北京三快在线科技有限公司      50702   ['技能培训', '绩效奖金', '岗位晋升', '领导好']
# 978    上海          北京三快在线科技有限公司      50702   ['技能培训', '绩效奖金', '岗位晋升', '领导好']
# 979    上海          北京三快在线科技有限公司      50702   ['技能培训', '绩效奖金', '岗位晋升', '领导好']
#
# ...

# %%
df.avg.rank()
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 6871   NaN
# 6872   NaN
# 6873   NaN
# 6874   NaN
# 6875   NaN
# Name: avg, Length: 6876, dtype: float64

# %%
df['rank'] = df.avg.rank()

# %%
df
# Out:
#      city    companyFullName  companyId                  companyLabelList  \
# 0      上海     纽海信息技术(上海)有限公司       8581  ['技能培训', '节日礼物', '带薪年假', '岗位晋升']
# 1      上海   上海点荣金融信息服务有限责任公司      23177  ['节日礼物', '带薪年假', '岗位晋升', '扁平管理']
# 2      上海     上海晶樵网络信息技术有限公司      57561  ['技能培训', '绩效奖金', '岗位晋升', '管理规范']
# 3      上海  杭州数云信息技术有限公司上海分公司       7502  ['绩效奖金', '股票期权', '五险一金', '通讯津贴']
# 4      上海     上海银基富力信息技术有限公司     130876  ['年底双薪', '通讯津贴', '定期体检', '绩效奖金']
# ...   ...                ...        ...                               ...
# 6871   北京     北京亿盛融华投资管理有限公司     151898                               NaN
# 6872   北京     北京亿盛融华投资管理有限公司     151898                               NaN
# 6873   北京     北京亿盛融华投资管理有限公司     151898                               NaN
# 6874   北京     北京亿盛融华投资管理有限公司     151898                               NaN
# 6875   北京     北京亿盛融华投资管理有限公司     151898                               NaN
#
#      companyShortName companySize           businessZones  firstType  \
# ...

# %%
df.describe()
# Out:
#            companyId    positionId  avg  rank
# count    6876.000000  6.876000e+03  0.0   0.0
# mean    56473.470477  2.188696e+06  NaN   NaN
# std     48416.947813  4.472044e+05  NaN   NaN
# min        43.000000  8.030700e+04  NaN   NaN
# 25%     10003.000000  2.049360e+06  NaN   NaN
# 50%     46668.000000  2.352736e+06  NaN   NaN
# 75%    101076.000000  2.495215e+06  NaN   NaN
# max    157744.000000  2.583183e+06  NaN   NaN

# %%
df['bins'] = pd.cut(df.topSalary.bins = [0,5,10,20,100],labels=['0~5','5~10','10~20','20~100'])
# Out:
#   File "<ipython-input-17-90bc22359c6f>", line 1
#     df['bins'] = pd.cut(df.topSalary.bins = [0,5,10,20,100],labels=['0~5','5~10','10~20','20~100'])
#                        ^
# SyntaxError: keyword can't be an expression

# %%
df.groupby(by = ['city','workYear']).mean()
# Out:
#                    companyId    positionId  avg  rank
# city workYear
# 上海   1-3年       56044.512422  2.104263e+06  NaN   NaN
#      10年以上      50283.500000  2.186072e+06  NaN   NaN
#      1年以下       66486.562500  2.335498e+06  NaN   NaN
#      3-5年       56149.964809  2.132500e+06  NaN   NaN
#      5-10年      63723.000000  2.206422e+06  NaN   NaN
# ...                      ...           ...  ...   ...
# 长沙   1-3年       44605.555556  2.166399e+06  NaN   NaN
#      3-5年       44933.900000  2.178290e+06  NaN   NaN
#      5-10年       7382.000000  7.452570e+05  NaN   NaN
#      不限         98598.000000  2.201182e+06  NaN   NaN
#      应届毕业生     149263.000000  2.430719e+06  NaN   NaN
#
# [75 rows x 4 columns]

# %%
for k in df.groupby(by = 'city'):
    print(k[1])
# Out:
#     city    companyFullName  companyId                  companyLabelList  \
# 0     上海     纽海信息技术(上海)有限公司       8581  ['技能培训', '节日礼物', '带薪年假', '岗位晋升']
# 1     上海   上海点荣金融信息服务有限责任公司      23177  ['节日礼物', '带薪年假', '岗位晋升', '扁平管理']
# 2     上海     上海晶樵网络信息技术有限公司      57561  ['技能培训', '绩效奖金', '岗位晋升', '管理规范']
# 3     上海  杭州数云信息技术有限公司上海分公司       7502  ['绩效奖金', '股票期权', '五险一金', '通讯津贴']
# 4     上海     上海银基富力信息技术有限公司     130876  ['年底双薪', '通讯津贴', '定期体检', '绩效奖金']
# ..   ...                ...        ...                               ...
# 975   上海       北京三快在线科技有限公司      50702   ['技能培训', '绩效奖金', '岗位晋升', '领导好']
# 976   上海       北京三快在线科技有限公司      50702   ['技能培训', '绩效奖金', '岗位晋升', '领导好']
# 977   上海       北京三快在线科技有限公司      50702   ['技能培训', '绩效奖金', '岗位晋升', '领导好']
# 978   上海       北京三快在线科技有限公司      50702   ['技能培训', '绩效奖金', '岗位晋升', '领导好']
# 979   上海       北京三快在线科技有限公司      50702   ['技能培训', '绩效奖金', '岗位晋升', '领导好']
#
#     companyShortName companySize           businessZones firstType secondType  \
# ...
